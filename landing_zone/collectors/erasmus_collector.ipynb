# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
# This script scrapes the Erasmus Mundus catalogue for program links from pages 6 to 11.

# Catalog URL
base_url = "https://www.eacea.ec.europa.eu/scholarships/erasmus-mundus-catalogue_en"

# Function to get the links from a specific page
def get_program_links(page_number):
    url = f"{base_url}?page={page_number}"
    response = requests.get(url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        program_links = soup.find_all('a', href=True)
        links = [a['href'] for a in program_links if "http" in a['href'] and "europa" not in a['href']]
        return links
    else:
        print(f"Failed to retrieve page {page_number}")
        return []

# Collect links from pages 6 to 11 (indexes 5 to 10)
program_links = []
for i in range(5, 11):
    links = get_program_links(i)
    program_links += links  # or use program_links.extend(links)

# Print all collected links
print("All Program Links from Pages 6 to 11:")
for link in program_links:
    print(link)
# Out:
# All Program Links from Pages 6 to 11:
# http://www.master-goals.eu/
# https://www.coasthazar.eu
# https://www.ntnu.edu/studies/mscomem
# https://cartographymaster.eu/
# https://www.master-promise.eu/
# https://www.tpti.eu/en/
# https://emildai.eu
# https://islandsmaster.eu/
# http://www.quanteem.eu
# https://emjm-sbbe.eu
# http://www.agrifoodmaster.eu/
# https://www.eu-conexus.eu/en/marine-biotechnology/
# https://masterchemoinfo.u-strasbg.fr/
# https://transnationalgermanstudies.eu/en/programme/
# http://www.master-quarmen.eu/
# http://www.mbuild.eu/
# https://www.master-mass.eu/
# https://www.amir-em-master.com/
# https://www.emmir.org/
# http://sustainabledrugdiscovery.eu
# https://mastergeotech.info/
# https://cyberus.univ-ubs.fr/en/index.html
# https://master-dream.ec-nantes.fr/
# https://www.emmie.uliege.be/cms/c_7950389/en/emmie
# https://www.imete.eu/
# https://msc-frp.org/
# http://www.cyber-t.eu/
# https://www.master-egei.eu/
# https://www.master-ediss.eu
# https://choreomundus.org/
# https://www.emmcchir.org/
# https://www.emcl.eu/
# http://www.emecs.eu
# http://glodep.eu/
# https://globalsecuritylaw-erasmusmundus.eu/
# https://www.erasmuswop.org
# http://www.aquah.eu
# http://www.imbrsea.eu/
# http://www.imrd.ugent.be/
# http://securityintelligence-erasmusmundus.eu/
# http://www.intermaths.eu/
# https://jemaro.ec-nantes.fr/
# http://www.kinoeyes.eu/
# http://www.master-lascala.eu/
# https://lct-master.org/
# http://ifrosmaster.org/
# http://www.maeh-mundus.eu/
# http://www.maiamaster.org/
# http://infectious-diseases-one-health.eu/
# http://www.maisi-project.eu/
# https://history.ceu.edu/history-public-sphere-emjmd-iuep-program
# https://www.imt-atlantique.fr/en/study/msc/emjmd-me3plusqJaTLx94UxC2zIVi2A$
# https://www.medfor.eu/
# http://www.mediaartscultures.eu/mediaac/
# http://merconsortium.eu/
# http://www.master-mir.eu/
# http://genial.univ-lorraine.fr/
# https://gemmaerasmusmundus.eu/
# https://www.gem-msc.eu/
# http://www.em-master-fusion.org/
# https://www.master-mitra.eu/en/
# http://www.europeanforestry.eu/
# https://iiw.kuleuven.be/english/food4s/
# http://masterfoodidentity.com/
# http://www.fipdes.eu/
# http://www.murcs.eu/
# http://master-nanomed.eu/
# https://www.neurasmus.u-bordeaux.fr/
# https://nohanet.org/masters
# http://www.emm-nucphys.eu/
# http://www.master-pangea.eu/
# http://www.euroculturemaster.eu/
# https://eswochy.eu/
# https://web.em-petal.eu/
# http://www.epsmaster.eu/
# http://master-economics-qem.univ-paris1.fr/
# https://emplant-master.eu/
# https://master-radmep.org/
# http://www.reanima.eu/
# https://www.master-remplus.eu/
# http://se4gd.eu/
# http://www.master-seas40.unina.it/
# https://secclo.eu/
# https://sinrem.eu/
# https://ssi-master.eu/
# http://www.emjmdsteps.eu/
# https://master-strains.eu/
# https://www.master-sucat.eu/
# http://www.emm-nano.org/
# https://mundusjournalism.com/
# https://www.tise-master.eu/
# http://emissmaster.omu.edu.tr/
# http://www.emhrpp.com/
# https://master-waves.eu/
# https://we-team.education/
# https://www.eusmat.net/international-studies/master/amase/
# http://www.nas.boku.ac.at/nuwi/emabg/
# https://www.eimas.uni-bayreuth.de/en/
# https://www.analyticalchemistry.eu/
# https://www.docnomads.eu/
# https://cosi-master.eu/
# https://www.master-cne.eu/
# https://www.cle.unibo.it/
# https://www.jointdegree.eu/de/circle-erasmus-mundus-international-masters-programme-on-circular-economy/
# https://erasmusmundus-ceeres.eu/
# https://master-bioref.eu
# https://master-biopham.eu/
# https://www.bioceb.eu/
# https://bimaplus.org/
# http://www.beinprecisionmedicine.org/
# https://bdma.ulb.ac.be/bdma/
# http://www.master-asc.org/
# http://www.afepa.eu
# http://www.4cities.eu

# %%
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
import json

i = 1
programs_json = {}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

title_prefixes = ("Erasmus Mundus Master", "International MSc", "International Master")

def extract_titles(soup):
    titles = []
    title_tag = soup.find("title")
    if title_tag and title_tag.text.strip():
        titles.append(title_tag.text.strip().replace('\xa0',' ').replace('Home - ',''))

    for tag in ["h1", "h2", "h3"]:
        for heading in soup.find_all(tag):
            heading_text = heading.text.strip()
            for prefix in title_prefixes:
                if prefix.lower() in heading_text.lower():                
                    titles.append(heading_text.replace('\xa0',' ').replace('Home - ',''))
    return list(set(titles))

for link in program_links:
    try:
        programs_json[f"p{i}"] = {
            "url": link,
            "pages": []
        }

        response = requests.get(link, headers=headers, timeout=10)
        response.raise_for_status()

        if "text/html" not in response.headers.get("Content-Type", ""):
            print(f"Skipping non-HTML link: {link}")
            continue

        soup = BeautifulSoup(response.content, "html.parser")
        program_titles = extract_titles(soup)
        programs_json[f"p{i}"]["titles"] = program_titles

        canonical_tag = soup.find("link", rel="canonical")
        program_base = urljoin(link, canonical_tag['href']) if canonical_tag and canonical_tag.get('href') else link

        # Add base page
        programs_json[f"p{i}"]["pages"].append({
            "url": program_base,
            "html": BeautifulSoup(requests.get(program_base, headers=headers).content, "html.parser").prettify()
        })

        # Add subpages
        sub_links = soup.find_all("a", href=True)
        parsed_url = urlparse(program_base)
        domain = parsed_url.netloc.replace('www.', '')

        for sub_link in sub_links:
            full_sub_link_url = urljoin(link, sub_link['href'])
            if domain in full_sub_link_url and 'http' in full_sub_link_url and not any(d["url"] == full_sub_link_url for d in programs_json[f"p{i}"]["pages"]):
                try:
                    sub_response = requests.get(full_sub_link_url, headers=headers, timeout=10)
                    sub_response.raise_for_status()

                    if "text/html" in sub_response.headers.get("Content-Type", ""):
                        html = BeautifulSoup(sub_response.content, "html.parser").prettify()
                        programs_json[f"p{i}"]["pages"].append({
                            "url": full_sub_link_url,
                            "html": html
                        })
                    else:
                        print(f"Skipped non-HTML subpage: {full_sub_link_url}")
                except Exception as sub_e:
                    print(f"Error fetching subpage {full_sub_link_url}: {sub_e}")
                    continue

        # Generate domain-based filename
        parsed_domain = urlparse(link).netloc.replace("www.", "").replace(".", "_")
        filename = f"program_{parsed_domain}.json"

        with open(filename, "w", encoding="utf-8") as f:
            json.dump(programs_json[f"p{i}"], f, indent=4, ensure_ascii=False)

        print(f"Saved: {filename}")

    except (requests.RequestException, ValueError) as e:
        print(f"Skipping {link} due to error: {e}")
        continue

    i += 1
# Out:
# Saved: program_master-goals_eu.json
# Saved: program_coasthazar_eu.json
# Skipped non-HTML subpage: https://www.ntnu.edu/documents/1310180250/0/Comem%2B_Brochure+202324.pdf/a3c2894e-1701-d06e-03cc-5cc8eaffaf85?t=1697447978748
# Error fetching subpage https://www.ntnu.edu/c/portal/login?p_l_id=1311043821: 403 Client Error: Forbidden for url: https://www.ntnu.edu/c/portal/login?p_l_id=1311043821
# Saved: program_ntnu_edu.json
# Error fetching subpage https://cartographymaster.eu/thesis: 404 Client Error: Not Found for url: https://cartographymaster.eu/thesis
# Skipped non-HTML subpage: http://cartographymaster.eu/wp-content/documents/CARTOGRAPHY_Student_Handbook.pdf
# Saved: program_cartographymaster_eu.json
# Saved: program_master-promise_eu.json
# Error fetching subpage https://www.tpti.eu/en/presentation/partners/universities.html: 404 Client Error: Not Found for url: https://www.tpti.eu/en/presentation/partners/universities.html
# Error fetching subpage https://www.tpti.eu/en/presentation/partners/cultural-institutions.html: 404 Client Error: Not Found for url: https://www.tpti.eu/en/presentation/partners/cultural-institutions.html
# Error fetching subpage https://www.tpti.eu/en/component/sppagebuilder/?Itemid=601: 404 Client Error: Not Found for url: https://www.tpti.eu/en/component/sppagebuilder/?Itemid=601
# Skipped non-HTML subpage: https://www.tpti.eu/images/Brochure/Brochure_TPTI_UK_Compressed.pdf
# Skipped non-HTML subpage: https://www.tpti.eu/images/Actualites/Cafeweb/Seance_4_cafe_web.pdf
# Skipped non-HTML subpage: https://www.tpti.eu/images/Actualites/Webinar/Seance_2_webminar.png
# Skipped non-HTML subpage: https://www.tpti.eu/images/Actualites/Event/Programme_La_femme_les_espaces_dhabitation.pdf
# Skipped non-HTML subpage: https://www.tpti.eu/images/Actualites/Workshop/ProgrammeW2024.pdf
# Error fetching subpage https://www.tpti.eu/en/component/sppagebuilder/?Itemid=601: 404 Client Error: Not Found for url: https://www.tpti.eu/en/component/sppagebuilder/?Itemid=601
# Saved: program_tpti_eu.json
# Saved: program_emildai_eu.json
# Saved: program_islandsmaster_eu.json
# Skipped non-HTML subpage: https://www.quanteem.eu/wp-content/uploads/QuanTEEM-Syllabus.pdf
# Skipped non-HTML subpage: https://www.quanteem.eu/wp-content/uploads/QuanTEEM-Model-Student-Agreement.pdf
# Skipped non-HTML subpage: https://www.quanteem.eu/wp-content/uploads/QuanTEEM-Flyer.jpg
# Skipped non-HTML subpage: https://www.quanteem.eu/wp-content/uploads/QuanTEEM-Appeal-procedure.pdf
# Saved: program_quanteem_eu.json
# Skipped non-HTML subpage: https://emjm-sbbe.eu/wp-content/uploads/2022/05/europe-partners-map.jpg
# Saved: program_emjm-sbbe_eu.json
# Skipped non-HTML subpage: https://agrifoodmaster.eu/uploads/1/4/0/7/140798836/dafm_application_guide_intake_4.pdf
# Skipped non-HTML subpage: http://www.agrifoodmaster.eu/uploads/1/4/0/7/140798836/en-co-funded-by-the-eu-pos_orig.jpg
# Saved: program_agrifoodmaster_eu.json
# Error fetching subpage https://innovationhub.eu-conexus.eu/: HTTPSConnectionPool(host='innovationhub.eu-conexus.eu', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)')))
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/12/jointmaster_brochure_2025_1.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/11/jmpmb_-admission_procedure_and_calendar_2025_approved_by_ac.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/11/jmpmb_-erasmus-mundus-scholarships_-2025_approved_by_ac.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2022/11/JMPMB.-Erasmus-Mundus-scholarships.-2023.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2025/03/JMPMB-Selection-results.-Eligibility-and-Assessment-2025-2026-Final-version-signed.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/07/Academic-Calendar-2024-2025_-Final-version-29_04.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2022/01/Annex-7.-SER.-ECTS-Course-Catalogue.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2022/03/JMPMB.-QA-guidelines_compressed.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2022/03/JMPMB.-Students-assessment_compressed.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2023/02/JMPMB-Internship-guidelines-and-annexes_v2.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2025/02/FAQS-2025.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2023/11/JMPMB.-Master-thesis-guidelines.-October-2023-Approved-by-AC.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2023/09/M1.5-Blue-Innovation-Day_final-version.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/01/Joint-training-concept-on-integration-and-academic-success.pdf
# Skipped non-HTML subpage: https://www.eu-conexus.eu/wp-content/uploads/2024/07/compedium-innovations-2024.pdf
# Saved: program_eu-conexus_eu.json
# Saved: program_masterchemoinfo_u-strasbg_fr.json
# Saved: program_transnationalgermanstudies_eu.json
# Skipped non-HTML subpage: http://www.master-quarmen.eu/images/custom/docs/Student handbook Quarmen_032024.pdf
# Skipped non-HTML subpage: http://www.master-quarmen.eu/images/custom/docs/Quarmen_Appeal_procedure.pdf
# Skipped non-HTML subpage: http://www.master-quarmen.eu/images/custom/docs/Student Agreement template 2024.pdf
# Skipped non-HTML subpage: http://www.master-quarmen.eu/images/custom/docs/Flyer_QUARMEN_2024.pdf
# Saved: program_master-quarmen_eu.json
# Saved: program_mbuild_eu.json
# Saved: program_master-mass_eu.json
# Saved: program_amir-em-master_com.json
# Saved: program_emmir_org.json
# Error fetching subpage http://sustainabledrugdiscovery.eu/finances: 404 Client Error: Not Found for url: https://sustainabledrugdiscovery.eu/finances
# Saved: program_sustainabledrugdiscovery_eu.json
# Error fetching subpage https://mastergeotech.info/ https:/twitter.com/Mastergeotech: 404 Client Error: Not Found for url: https://mastergeotech.info/%20https:/twitter.com/Mastergeotech
# Error fetching subpage https://mastergeotech.info/ https:/twitter.com/Mastergeotech: 404 Client Error: Not Found for url: https://mastergeotech.info/%20https:/twitter.com/Mastergeotech
# Saved: program_mastergeotech_info.json
# Saved: program_cyberus_univ-ubs_fr.json
# Error fetching subpage https://twitter.com/intent/tweet?url=https%3A%2F%2Fmaster-dream.ec-nantes.fr%2F&text=European+Master+in+Dynamics+of+renewables-based...: 400 Client Error: Bad Request for url: https://x.com/intent/tweet?url=https%3A%2F%2Fmaster-dream.ec-nantes.fr%2F&text=European+Master+in+Dynamics+of+renewables-based...
# Error fetching subpage https://master-dream.ec-nantes.fr/en/linkedin: 403 Client Error: Forbidden for url: https://fr.linkedin.com/company/dream-european-master
# Saved: program_master-dream_ec-nantes_fr.json
# Saved: program_emmie_uliege_be.json
# Saved: program_imete_eu.json
# Saved: program_msc-frp_org.json
# Saved: program_cyber-t_eu.json
# Saved: program_master-egei_eu.json
# Saved: program_master-ediss_eu.json
# Error fetching subpage https://choreomundus.org/wp-admin/: 404 Client Error: Not Found for url: https://choreomundus.org/not_found
# Saved: program_choreomundus_org.json
# Skipped non-HTML subpage: https://www.emmcchir.org/resources/Promotion/ChIR_pamphlet_v2_light.pdf
# Skipped non-HTML subpage: https://www.emmcchir.org/files/gallery_image-269.png
# Skipped non-HTML subpage: https://www.emmcchir.org/files/gallery_image-270.png
# Skipped non-HTML subpage: https://www.emmcchir.org/files/gallery_image-271.png
# Skipped non-HTML subpage: https://www.emmcchir.org/files/gallery_image-272.png
# Saved: program_emmcchir_org.json
# Skipped non-HTML subpage: https://www.emcl.eu/files/CA-new.pdf
# Saved: program_emcl_eu.json
# Saved: program_emecs_eu.json
# Saved: program_glodep_eu.json
# Skipping https://globalsecuritylaw-erasmusmundus.eu/ due to error: HTTPSConnectionPool(host='globalsecuritylaw-erasmusmundus.eu', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x10742ddf0>: Failed to resolve 'globalsecuritylaw-erasmusmundus.eu' ([Errno 8] nodename nor servname provided, or not known)"))
# Skipping https://www.erasmuswop.org due to error: HTTPSConnectionPool(host='www.erasmuswop.org', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x10724f970>, 'Connection to www.erasmuswop.org timed out. (connect timeout=10)'))
# Saved: program_aquah_eu.json
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/phytoplankton-diatoms-ocean-food-chains-foundations-fishes.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/CSIRO_ScienceImage_2319_Using_the_CTD_Collector_in_Antarctica.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/DSC_2207.JPG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/marpolandgovern.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/Fisher_iris_versicolor_sepalwidth.svg_.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/gis-layers-diagram.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/CampusMil%C3%A1n10.JPG.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/Cabecera%20recursos-marinos.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/spain-1766739_960_720.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/scientific%20dissemination2.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/field.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/Testings_0.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/scuba.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/16736023655_2b160e6f05_b.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/pp1.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/pt.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/courses/stakeholder.jpg
# Error fetching subpage http://www.imbrsea.eu/about-imbrsea-0: 404 Client Error: Not Found for url: http://www.imbrsea.eu/about-imbrsea-0
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/sterreS8.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/2010pm099921h8759.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/w940q85_sterre13.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/sterre3_0.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/biologia.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/1572357230_399980_1572357419_miniatura_normal.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/uied.jpg-591x336.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/00_3.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/209_0.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/02_entrada-universidade-gambelas2-1024x683.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/UiB3%20%282%29.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/UiB4.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/UiB2.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/UiB.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/ResearchCruise2.PNG
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Brest.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/udbo-cover.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/IMG_0770.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/banner-galwaycampus_6.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/GMIT-%20Marine%20and%20Freshwater%20research%20center.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/GMIT.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/sorbonne.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Banyuls-01.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/station-biologique-roscoff-sbr-2265.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Roscoff_SU_LArdhuin3.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Villefranche_sur_Mer_SU_LArdhuin5.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Roscoff_SU_LArdhuin2.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/dellaMarche.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/univpm-ing-3.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Universit%C3%A0.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/embrc.png
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/EMBRC_web6.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/Critters-for-EMBRC-project-page-400x300.jpg
# Skipped non-HTML subpage: http://www.imbrsea.eu/sites/default/files/gallery-images/embrc-eric-800x450.jpg
# Error fetching subpage http://cohort2020.imbrsea.eu/about-imbrsea-0: 503 Server Error: Service Unavailable for url: http://cohort2020.imbrsea.eu/about-imbrsea-0
# Error fetching subpage http://cohort2020.imbrsea.eu/become-partner: 503 Server Error: Service Unavailable for url: http://cohort2020.imbrsea.eu/become-partner
# Error fetching subpage http://cohort2020.imbrsea.eu/consortium-agreement: 503 Server Error: Service Unavailable for url: http://cohort2020.imbrsea.eu/consortium-agreement
# Error fetching subpage http://cohort2020.imbrsea.eu/privacy-plicy: 503 Server Error: Service Unavailable for url: http://cohort2020.imbrsea.eu/privacy-plicy
# Error fetching subpage http://www.imbrsea.eu/user/register: 403 Client Error: Forbidden for url: http://www.imbrsea.eu/user/register
# Saved: program_imbrsea_eu.json
# Saved: program_imrd_ugent_be.json
# Saved: program_securityintelligence-erasmusmundus_eu.json
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/laquila: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/laquila
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/toronto: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/toronto
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/brno: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/brno
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/gdansk: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/gdansk
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/aveiro: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/aveiro
# Error fetching subpage http://www.intermaths.eu/double-degree/partners/karlstad: 404 Client Error: Not Found for url: https://www.intermaths.eu/double-degree/partners/karlstad
# Saved: program_intermaths_eu.json
# Error fetching subpage https://twitter.com/intent/tweet?url=https%3A%2F%2Fjemaro.ec-nantes.fr%2F&text=Home+JEMARO: 400 Client Error: Bad Request for url: https://x.com/intent/tweet?url=https%3A%2F%2Fjemaro.ec-nantes.fr%2F&text=Home+JEMARO
# Error fetching subpage https://jemaro.ec-nantes.fr/english-version/linkedin: 403 Client Error: Forbidden for url: https://fr.linkedin.com/company/jemaro-master
# Saved: program_jemaro_ec-nantes_fr.json
# Saved: program_kinoeyes_eu.json
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/Student handbook LASCALA 2022.pdf
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/lascala/Appeal_procedure.pdf
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/lascala/Student_Agreement_template.pdf
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/Poster_LASCALA_012021.pdf
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/Flyer_LASCALA_012021.pdf
# Skipped non-HTML subpage: http://www.master-lascala.eu/images/custom/QA_internship_mobility_rules_2022.pdf
# Saved: program_master-lascala_eu.json
# Saved: program_lct-master_org.json
# Saved: program_ifrosmaster_org.json
# Saved: program_maeh-mundus_eu.json
# Saved: program_maiamaster_org.json
# Saved: program_infectious-diseases-one-health_eu.json
# Saved: program_maisi-project_eu.json
# Skipping https://history.ceu.edu/history-public-sphere-emjmd-iuep-program due to error: 404 Client Error: Not Found for url: https://historicalstudies.ceu.edu/history-public-sphere-emjmd-iuep-program
# Error fetching subpage http://twitter.com/share?url=https://www.imt-atlantique.fr/en/study/masters/emjmd/me3plus&amp;size=l&amp;count=none: 400 Client Error: Bad Request for url: https://x.com/share?url=https://www.imt-atlantique.fr/en/study/masters/emjmd/me3plus&amp;size=l&amp;count=none
# Saved: program_imt-atlantique_fr.json
# Error fetching subpage https://www.medfor.eu/university/university-lisbon-portugal: 404 Client Error: Not Found for url: https://www.medfor.eu/university/university-lisbon-portugal
# Error fetching subpage https://www.medfor.eu/university/university-padova-italy: 404 Client Error: Not Found for url: https://www.medfor.eu/university/university-padova-italy
# Error fetching subpage https://www.medfor.eu/university/university-lleida-spain: 404 Client Error: Not Found for url: https://www.medfor.eu/university/university-lleida-spain
# Error fetching subpage https://www.medfor.eu/university/karadeniz-technical-university-turkey: 404 Client Error: Not Found for url: https://www.medfor.eu/university/karadeniz-technical-university-turkey
# Error fetching subpage https://www.medfor.eu/university/university-valladolid-spain: 404 Client Error: Not Found for url: https://www.medfor.eu/university/university-valladolid-spain
# Error fetching subpage https://www.medfor.eu/university/university-tuscia-italy: 404 Client Error: Not Found for url: https://www.medfor.eu/university/university-tuscia-italy
# Error fetching subpage https://www.medfor.eu/university/catholic-university-portugal-portugal: 404 Client Error: Not Found for url: https://www.medfor.eu/university/catholic-university-portugal-portugal
# Saved: program_medfor_eu.json
# Saved: program_mediaartscultures_eu.json
# Skipped non-HTML subpage: https://merconsortium.eu/wp-content/uploads/2018/01/Thesis-Project-Monitoring.doc
# Saved: program_merconsortium_eu.json
# Saved: program_master-mir_eu.json
# Saved: program_genial_univ-lorraine_fr.json
# Error fetching subpage https://gemmaerasmusmundus.eu/informacion/restringido/acceso: 404 Client Error: Not Found for url: https://gemmaerasmusmundus.eu/informacion/restringido/acceso
# Error fetching subpage https://gemmaerasmusmundus.eu/permanencia: 404 Client Error: Not Found for url: https://gemmaerasmusmundus.eu/permanencia
# Error fetching subpage https://gemmaerasmusmundus.eu/accesibilidad: 404 Client Error: Not Found for url: https://gemmaerasmusmundus.eu/accesibilidad
# Error fetching subpage https://gemmaerasmusmundus.eu/condiciones-legales: 404 Client Error: Not Found for url: https://gemmaerasmusmundus.eu/condiciones-legales
# Saved: program_gemmaerasmusmundus_eu.json
# Skipped non-HTML subpage: https://www.gem-msc.eu/about-gem-msc/gem-msc-study-guide-2023.pdf
# Saved: program_gem-msc_eu.json
# Saved: program_em-master-fusion_org.json
# Error fetching subpage https://www.master-mitra.eu/about-mitra/consortium: 404 Client Error: Not Found for url: https://www.master-mitra.eu/fr/about-mitra/consortium
# Saved: program_master-mitra_eu.json
# Saved: program_europeanforestry_eu.json
# Saved: program_iiw_kuleuven_be.json
# Error fetching subpage mailto:?subject=Master’s in Local products and Traditional Food (Food Identity)&body=https://www.groupe-esa.com/en/formation/master-food-identity/: No connection adapters were found for 'mailto:?subject=Master’s in Local products and Traditional Food (Food Identity)&body=https://www.groupe-esa.com/en/formation/master-food-identity/'
# Error fetching subpage https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf: HTTPSConnectionPool(host='www.groupe-esa.com', port=443): Read timed out. (read timeout=10)
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Error fetching subpage https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf: HTTPSConnectionPool(host='www.groupe-esa.com', port=443): Read timed out. (read timeout=10)
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Error fetching subpage https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf: HTTPSConnectionPool(host='www.groupe-esa.com', port=443): Read timed out. (read timeout=10)
# Skipped non-HTML subpage: https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf
# Error fetching subpage https://www.groupe-esa.com/en/formation/master-food-identity/?print=pdf: HTTPSConnectionPool(host='www.groupe-esa.com', port=443): Read timed out. (read timeout=10)
# Saved: program_masterfoodidentity_com.json
# Error fetching subpage http://www.fipdes.eu/?The-Cookbook-Initiative: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?The-Cookbook-Initiative
# Error fetching subpage http://www.fipdes.eu/?The-Cooking-Passport-292: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?The-Cooking-Passport-292
# Error fetching subpage http://www.fipdes.eu/?How-to-buy-the-book-293: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?How-to-buy-the-book-293
# Error fetching subpage http://www.fipdes.eu/?Industry-Contribution-81: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Industry-Contribution-81
# Error fetching subpage http://www.fipdes.eu/?Current-FIPDes-Industrial-Partners: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Current-FIPDes-Industrial-Partners
# Error fetching subpage http://www.fipdes.eu/?Collaboration-with-Danone-Nutricia-Research-155: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Collaboration-with-Danone-Nutricia-Research-155
# Error fetching subpage http://www.fipdes.eu/?Become-a-partner-126: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Become-a-partner-126
# Error fetching subpage http://www.fipdes.eu/?Symrise-Visit: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Symrise-Visit
# Error fetching subpage http://www.fipdes.eu/?CATEX-Exhibition-2025: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?CATEX-Exhibition-2025
# Error fetching subpage http://www.fipdes.eu/?Symrise-Visit: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?Symrise-Visit
# Error fetching subpage http://www.fipdes.eu/?CATEX-Exhibition-2025: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/?CATEX-Exhibition-2025
# Error fetching subpage http://www.fipdes.eu/spip.php?article6: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/spip.php?article6
# Error fetching subpage http://www.fipdes.eu/spip.php?article20: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/spip.php?article20
# Error fetching subpage http://www.fipdes.eu/spip.php?article24: 503 Server Error: Service Temporarily Unavailable for url: http://www.fipdes.eu/spip.php?article24
# Error fetching subpage http://fipdes.eu: 503 Server Error: Service Temporarily Unavailable for url: http://fipdes.eu/
# Saved: program_fipdes_eu.json
# Skipped non-HTML subpage: https://murcs.eu/wp-content/uploads/MUrCS_Newsletter_2022_1.pdf
# Skipped non-HTML subpage: https://murcs.eu/wp-content/uploads/MUrCS_Newsletter_2022_2.pdf
# Skipped non-HTML subpage: https://murcs.eu/wp-content/uploads/MURCS_JUN_2020_Updated.mp4
# Skipped non-HTML subpage: https://murcs.eu/wp-content/uploads/WelcomePackMUrCS2022.pdf
# Saved: program_murcs_eu.json
# Saved: program_master-nanomed_eu.json
# Skipped non-HTML subpage: https://www.neurasmus.u-bordeaux.fr/wp-content/uploads/2025/02/Neurasmus-2025-European-master-in-Neuroscience-v2.pdf
# Skipped non-HTML subpage: https://www.neurasmus.u-bordeaux.fr/wp-content/uploads/2025/02/Neurasmus-2025-European-master-in-Neuroscience-v2.pdf
# Saved: program_neurasmus_u-bordeaux_fr.json
# Error fetching subpage https://nohanet.org/data/erasmus/Guest Scholar Application Form.pdf: 403 Client Error: Forbidden for url: https://nohanet.org/data/erasmus/Guest%20Scholar%20Application%20Form.pdf
# Skipped non-HTML subpage: https://nohanet.org/data/masters/CONSORTIUM AGREEMENT 2020 (2).pdf
# Skipped non-HTML subpage: https://nohanet.org/data/masters/Study & Examination regulations.pdf
# Skipped non-HTML subpage: https://nohanet.org/data/masters/IQH_NOHA_Internal Quality Handbook.pdf
# Skipped non-HTML subpage: https://nohanet.org/data/masters/ANNEX IV NOHA +STUDENT AGREEMENT template.pdf
# Skipped non-HTML subpage: https://nohanet.org/uploads/master/120/en/downloads/NOHA%20Appeal%20Form.docx
# Skipped non-HTML subpage: https://nohanet.org/data/masters/NOHA Complaint Procedure and Form.pdf
# Saved: program_nohanet_org.json
# Saved: program_emm-nucphys_eu.json
# Error fetching subpage https://master-pangea.eu/testimonies/: HTTPSConnectionPool(host='master-pangea.eu', port=443): Read timed out. (read timeout=10)
# Skipped non-HTML subpage: https://master-pangea.eu/wp-content/uploads/2014/10/logo-pangea-master.png
# Skipped non-HTML subpage: https://master-pangea.eu/wp-content/uploads/2022/01/nouveaux-logos.jpg
# Saved: program_master-pangea_eu.json
# Saved: program_euroculturemaster_eu.json
# Saved: program_eswochy_eu.json
# Skipped non-HTML subpage: https://web.em-petal.eu/wp-content/uploads/2019/07/PETaL-19-20-Academic-Calendar.pdf
# Skipped non-HTML subpage: https://web.em-petal.eu/wp-content/uploads/2019/12/PETaL-19-20-Exam-Schedule-and-Innovation-Seminar.pdf
# Skipped non-HTML subpage: https://web.em-petal.eu/wp-content/uploads/2020/02/Calendar_PETaL_19_20_Semester_2.pdf
# Skipped non-HTML subpage: https://web.em-petal.eu/wp-content/uploads/2019/01/PETaL-EMJMD-brochure.pdf
# Saved: program_web_em-petal_eu.json
# Skipped non-HTML subpage: https://epsmaster.eu/wp-content/uploads/2020/01/Inaugurace-21_10_2019_0109_web-1024x683.jpg
# Saved: program_epsmaster_eu.json
# Saved: program_master-economics-qem_univ-paris1_fr.json
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2021/02/0-Course-Catalogue-emPLANT.pdf
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2021/12/Leaflet_emPLANT.pdf
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2021/01/guest-lecturer-scholar-application-form-emPLANT.doc
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2020/03/emPLANT-selection-results-intake-3-Main-and-reserve-list.pdf
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2022/09/emPLANT-Student-Agreement.pdf
# Skipped non-HTML subpage: https://emplant-master.eu/wp-content/uploads/2021/05/emPLANT-selection-results-intake-1-Main-and-reserve-list-for-scholarships.pdf
# Saved: program_emplant-master_eu.json
# Error fetching subpage https://master-radmep.org/?page_id=250: 404 Client Error: Not Found for url: https://master-radmep.org/?page_id=250
# Error fetching subpage https://master-radmep.org/?share=twitter: 400 Client Error: Bad Request for url: https://x.com/intent/tweet?related=wordpressdotcom&text=RADMEP&url=https%3A%2F%2Fmaster-radmep.org%2F
# Saved: program_master-radmep_org.json
# Saved: program_reanima_eu.json
# Skipped non-HTML subpage: https://www.master-remplus.eu/wp-content/uploads/EMJMD-REM-brochure.pdf
# Skipped non-HTML subpage: https://www.master-remplus.eu/wp-content/uploads/REMPLUS-Student-Agreement-template.pdf
# Skipped non-HTML subpage: https://www.master-remplus.eu/wp-content/uploads/EMJMD-REM-brochure.pdf
# Skipped non-HTML subpage: https://www.master-remplus.eu/wp-content/uploads/EMJMD-REM-brochure.pdf
# Saved: program_master-remplus_eu.json
# Saved: program_se4gd_eu.json
# Saved: program_master-seas40_unina_it.json
# Error fetching subpage https://www.secclo.eu/?page_id=133: 404 Client Error: Not Found for url: https://www.secclo.eu/?page_id=133
# Saved: program_secclo_eu.json
# Saved: program_sinrem_eu.json
# Error fetching subpage https://ssi-master.eu/faq/: 404 Client Error: Not Found for url: https://ssi-master.eu/faq/
# Saved: program_ssi-master_eu.json
# Saved: program_emjmdsteps_eu.json
# Saved: program_master-strains_eu.json
# Skipped non-HTML subpage: https://www.master-sucat.eu/wp-content/uploads/sites/597/2022/06/EMJM_SuCat_Short_Pres.mp4
# Error fetching subpage https://www.master-sucat.eu/flux-rss/: 404 Client Error: Not Found for url: https://www.master-sucat.eu/flux-rss/
# Saved: program_master-sucat_eu.json
# Saved: program_emm-nano_org.json
# Error fetching subpage https://mundusjournalism.com/about-us/our-mundus-journalism-staff/: 404 Client Error: Not Found for url: https://mundusjournalism.com/about-us/our-mundus-journalism-staff/
# Saved: program_mundusjournalism_com.json
# Saved: program_tise-master_eu.json
# Skipped non-HTML subpage: http://emissmaster.omu.edu.tr/uploads/4th intake 2023-2025 emiSS SELECTION LIST for.pdf
# Skipped non-HTML subpage: http://emissmaster.omu.edu.tr/uploads/emiSS_Appeal-Form.docx
# Skipped non-HTML subpage: http://emissmaster.omu.edu.tr/uploads/Signed_Annex__no_1.pdf
# Skipped non-HTML subpage: http://emissmaster.omu.edu.tr/uploads/Declaration_of_honour_en_3.docx
# Saved: program_emissmaster_omu_edu_tr.json
# Error fetching subpage http://www.emhrpp.com/team: 404 Client Error: Not Found for url: https://www.emhrpp.com/team
# Saved: program_emhrpp_com.json
# Error fetching subpage https://twitter.com/MasterWaves?ref_src=twsrc%5Etfw%7Ctwcamp%5Eembeddedtimeline%7Ctwterm%5Eprofile%3AMasterWaves&ref_url=https%3A%2F%2Fmaster-waves.eu%2Fwaves-home: 400 Client Error: Bad Request for url: https://x.com/MasterWaves?ref_src=twsrc%5Etfw%7Ctwcamp%5Eembeddedtimeline%7Ctwterm%5Eprofile%3AMasterWaves&ref_url=https%3A%2F%2Fmaster-waves.eu%2Fwaves-home
# Error fetching subpage https://application.master-waves.eu/: HTTPSConnectionPool(host='application.master-waves.eu', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x10794efa0>: Failed to resolve 'application.master-waves.eu' ([Errno 8] nodename nor servname provided, or not known)"))
# Saved: program_master-waves_eu.json
# Saved: program_we-team_education.json
# Skipped non-HTML subpage: https://www.eusmat.net/sitemap_index.xml
# Saved: program_eusmat_net.json
# Saved: program_nas_boku_ac_at.json
# Saved: program_eimas_uni-bayreuth_de.json
# Skipped non-HTML subpage: http://each.ut.ee/EACH/wp-content/uploads/2017/09/Disclaimer.pdf
# Skipped non-HTML subpage: http://each.ut.ee/EACH/wp-content/uploads/2017/09/Privacy_statement_EMT.pdf
# Saved: program_analyticalchemistry_eu.json
# Saved: program_docnomads_eu.json
# Saved: program_cosi-master_eu.json
# Saved: program_master-cne_eu.json
# Saved: program_cle_unibo_it.json
# Skipping https://www.jointdegree.eu/de/circle-erasmus-mundus-international-masters-programme-on-circular-economy/ due to error: 404 Client Error: Not Found for url: https://www.jointdegree.eu/de/circle-erasmus-mundus-international-masters-programme-on-circular-economy/
# Saved: program_erasmusmundus-ceeres_eu.json
# Error fetching subpage https://master-bioref.eu/apply-now/: 404 Client Error: Not Found for url: https://master-bioref.eu/apply-now/
# Skipped non-HTML subpage: https://master-bioref.eu/wp-content/uploads/2014/10/logo-bioref-european-master-blc-1.png
# Saved: program_master-bioref_eu.json
# Error fetching subpage https://plateforme.master-biopham.eu/index.php: 503 Server Error: Service Unavailable for url: https://plateforme.master-biopham.eu/index.php
# Saved: program_master-biopham_eu.json
# Saved: program_bioceb_eu.json
# Saved: program_bimaplus_org.json
# Saved: program_beinprecisionmedicine_org.json
# Skipped non-HTML subpage: https://bdma.ulb.ac.be/files/Application_manuals_BDMA_September-2023-final-version.pdf
# Skipped non-HTML subpage: https://bdma.ulb.ac.be/files/BDMA_courses-1.pdf
# Skipped non-HTML subpage: https://bdma.ulb.ac.be/files/flyer2019-2020.pdf
# Skipped non-HTML subpage: https://bdma.ulb.ac.be/files/BDMAGuide2019-2020.pdf
# Saved: program_bdma_ulb_ac_be.json
# Saved: program_master-asc_org.json
# Skipped non-HTML subpage: https://www.ilr1.uni-bonn.de/afepa/media/afepa_ca_fully-signed_2019-1.pdf
# Skipped non-HTML subpage: https://www.ilr1.uni-bonn.de/afepa/media/advisory-board-2023.pdf
# Saved: program_afepa_eu.json
# Saved: program_4cities_eu.json

# %%
# Iterate over the programs_json to get all URLs from the "pages" key
all_urls=[]

for program_key, program_data in programs_json.items():
    test=[]
    test.append(program_data["titles"])
    # Extract URLs from the "pages" list
    for page in program_data["pages"]:
        test.append(page["url"])
    all_urls.append(test)

# %%
for i in all_urls:
    print(i[0])
# Out:
# ['Master GOALS - GOvernance & Administration of Leisure and Sports International Master']
# ['Erasmus Mundus | CoastHazar']
# ['Coastal and Marine Engineering and Management (MSCOMEMPLUS) - NTNU']
# ['Welcome to the Cartography M.Sc. programme']
# ['EMJM PROMISE – Erasmus Mundus Joint Master in Sustainable Mineral and Metal Processing Engineering']
# ['Master Techniques, Heritage, Territories of Industry - Erasmus Mundus+']
# ['EMILDAI']
# ['ISLANDS MSc – Islands and Sustainability']
# ['AN ERASMUS MUNDUS MASTER IN QUANTUM TECHNOLOGIES AND ENGINEERING', 'QUANTEEM, An engineering erasmus mundus master.']
# ['EMJM-SBBE – Sustainable Biomass and Bioproducts Engineering']
# ['DANUBE AGRIFOOD MASTER – JOINT MASTER PROGRAM - Home']
# ['Joint Master Programme in Marine Biotechnology - EU-CONEXUS']
# ['Erasmus Mundus Joint Master - ChEMoinformatics+ Unique in Europe']
# ['Programme - Transnational German Studies']
# ['Erasmus Mundus Quarmen Master', "International Master's programme in Quantum Science and Technology"]
# []
# ['Master in Astrophysics and Space Science – Erasmus Mundus Joint Master Degree']
# ['AMIR Erasmus Mundus : Master in Advanced Materials: Innovative Recycling - Erasmus EM Mundus']
# ['EMMIR - European Master in Migration and Intercultural Relations']
# ['Sustainable Drug Discovery – International Master']
# ['Mastergeotech Mastergeotech']
# ['Cyberus - Cyberus']
# ['European Master in Dynamics of renewables-based power systems (DREAM)']
# ['Home']
# ['HOME | imete']
# ['FRP++']
# ['Master in Cyberspace Behavior and E-therapy - Cyber-t']
# ['Erasmus Mundus Joint Master in Economics of Globalisation and European Integration  – A 2-year study programme for a Global career']
# ['EDISS – Erasmus Mundus Joint Master Degree Programme on the Engineering of Data-intensive Intelligent Software Systems']
# ['Choreomundus - International Master in Dance Knowledge, Practice and Heritage', 'Choreomundus – International Master in Dance Knowledge, Practice, and Heritage']
# ['Home | ChIR']
# ['EMCL-25']
# ['European Master in Embedded Computing Systems | An Erasmus Mundus Programme']
# ['GLODEP | Erasmus Mundus Joint Master Degree']
# ['International Master of Science in Health Management in Aquaculture']
# ['Home | IMBRSea']
# ['IMRD']
# []
# ['International MSc RealMaths  ■ Partner Universities', 'Admission round open for the International MSc RealMaths 2025', 'InterMaths Network', 'International MScREALMATHS • Mathematics for Real World Applications']
# ['Master JEMARO']
# ['KINOEYES KEM The European Film Masters - Kinoeyes | KEM The European Film Masters']
# ['Erasmus Mundus Lascala Master']
# ['Language & Communication Technologies – European Masters Program']
# ['Master IFROS – Erasmus mundus joint master in Intelligent Field Robotic Systems']
# ['MAEH']
# ['MAIA – Erasmus Mundus Joint Master in MedicAl Imaging and Applications']
# []
# ['MAiSI | Master of Arts in Sports Ethics and Integrity']
# ['Erasmus Mundus in Management and Engineering of Environment and Energy - About']
# ['MEDFOR - Mediterranean Forestry and Natural Resources Management']
# ['Media Arts Cultures - EMJMD | European Excellence Master']
# ['MER+ MER2030', 'Join the MER2030 Erasmus Mundus Master Degree']
# ["Master Mir – Erasmus Mundus joint Master's Degree"]
# ['GENIAL']
# ["Home page | Master's Degree in Women's and Gender Studies"]
# ['GEM Joint Master programme - ITC - GEM MSc']
# ['Home']
# ['Home']
# ['Master of Science in European Forestry']
# ['European Master of Sustainable Food Systems Engineering, Technology and Business']
# ["Master's in Local products and Traditional Food | Higher education in France"]
# ['FIPDes']
# ['Urban Climate and Sustainability – International Erasmus Mundus Joint Master of Science Programme']
# ['Nanomed | Université Paris Cité']
# ['Neurasmus : your Neuroscience master - Neurasmus | European master in neuroscience']
# ["NOHA Master's Programme - NOHA Network on Humanitarian Action — International Association of Universities"]
# ['European Master in Nuclear Physics']
# ['HOME - Master Pangea']
# ['Euroculture EMJM']
# ['eswochy.eu – European Joint Master in Social Work with Children and Youth']
# ['PETaL EMJMD – Play, Education, Toys & Languages – Just another WordPress site']
# ['EPS – Václav Havel Joint Masters Programme']
# ['Welcome to | Erasmus - QEM']
# ['Erasmus Mundus Master Program in Plant Breeding - emPLANT Master']
# []
# ['Homepage - RE:Anima - European Joint Master in Animation']
# ['International master', 'Master in Renewable Energy in the Marine Environment Master in Renewable Energy in the Marine Environment']
# ['SE4GD – Software engineering with a purpose']
# ['Master Seas 4.0 – Università degli Studi di Napoli Federico II']
# []
# ['International MSc in Sustainable and Innovative Natural Resource Management', 'SINReM – International Master of Science']
# ['Joint International Master in Smart Systems Integrated Solutions (SSIs) - SSIs', 'Joint International Master in Smart Systems Integrated Solutions', 'Joint International Master in Smart Systems Integrated Solutions (SSIs)']
# ['Erasmus Mundus Joint Master Degree STEPS - Home']
# ['Master Erasmus Mundus STRAINS Université de Lille']
# ['Master SuCat – Université de Poitiers', 'Erasmus Mundus Master in Sustainable Catalysis']
# ['Erasmus Mundus Master Nanoscience and Nanotechnology', 'EMM Nano | Erasmus Mundus']
# ["Erasmus Mundus Master's in Journalism, Media and Globalisation"]
# ['TISE']
# ['The Erasmus Mundus Master in Soil Science (emiSS)']
# ['Erasmus Mundus - Home']
# ['Master Waves | Home', 'ERASMUS MUNDUS MASTER WAVES']
# ['WE-TEAM']
# ['AMASE - European School of Materials | EUSMAT | Saarland University']
# ['European Master in Animal Biodiversity and Genomics – European Master in Animal Biodiversity and Genomics']
# ['European Interdisciplinary Master African Studies']
# ['Excellence in Analytical Chemistry']
# ['Home']
# []
# ['Master-cne – Erasmus Mundus Joint Master Degree', 'Erasmus Mundus Master Chemical NanoEngineering']
# ['Erasmus Mundus Master Course in European Literary Cultures', 'Erasmus Mundus Master Course in European Literary Cultures | Master CLE Erasmus Mundus']
# []
# ['Master Bioref']
# ['Master BioPham Erasmus Mundus Université de Lille']
# ['Bioceb - European Master in Biological and Chemical Engineering for a Sustainable Bioeconomy']
# ['BIM A+ European Master in BIM - Building Information Modelling']
# []
# ['BDMA – BDMA – Big Data Management and Analytics']
# ['ASC European Master']
# ['AFEPA homepage — AFEPA']
# ['4CITIES – Master Program in Urban Studies']

# %%
# all_urls
